# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 데이터셋 설명

# %%
## 데이터셋 설명

# %% [markdown]
# ## 1. 데이터 로드
# - medical_data.csv를 로드

# %%
df = pd.read_csv('medical_data.csv')
df
# Out:
#      inst_id      OC       sido  openDate  bedCount              instkind  \
# 0          1    open  choongnam  20071228     175.0      nursing_hospital
# 1          3    open  gyeongnam  19970401     410.0      general_hospital
# 2          4    open   gyeonggi  20161228     468.0      nursing_hospital
# 3          7    open    incheon  20000814     353.0      general_hospital
# 4          9    open  gyeongnam  20050901     196.0      general_hospital
# ..       ...     ...        ...       ...       ...                   ...
# 296      422    open    jeonnam  20050211     214.0      nursing_hospital
# 297      423   close  choongnam  20140618       NaN              hospital
# 298      426   close  gyeongbuk  19830705       NaN              hospital
# 299      427   close   gyeonggi  20070101     180.0      nursing_hospital
# 300      428    open      seoul  20011017       NaN  traditional_hospital
#
#           revenue        salary        profit          debt      netAsset  \
# ...

# %% [markdown]
# ## 2. 데이터의 처음 5개 값 출력

# %%
df.head(5)
# Out:
#    inst_id    OC       sido  openDate  bedCount          instkind  \
# 0        1  open  choongnam  20071228     175.0  nursing_hospital
# 1        3  open  gyeongnam  19970401     410.0  general_hospital
# 2        4  open   gyeonggi  20161228     468.0  nursing_hospital
# 3        7  open    incheon  20000814     353.0  general_hospital
# 4        9  open  gyeongnam  20050901     196.0  general_hospital
#
#         revenue        salary       profit          debt      netAsset  \
# 0  4.217530e+09  2.033835e+09  225169678.0  6.828260e+08  2.844460e+09
# 1           NaN           NaN          NaN           NaN           NaN
# 2  1.004522e+09  2.964023e+08   41864754.0  9.241434e+07  3.005088e+08
# 3  7.250734e+10  3.178605e+10  902830288.0  4.236380e+10  1.385710e+10
# 4  4.904354e+10  2.446078e+10   80749696.0  4.989811e+10  8.631164e+07
#
#    employee ownerChange
# 0      62.0        same
# 1     801.0        same
# 2     234.0        same
# 3     663.0        same
# ...

# %% [markdown]
# ## 3. 수치형 변수의 통계 정보 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   inst_id      301 non-null    int64
#  1   OC           301 non-null    object
#  2   sido         301 non-null    object
#  3   openDate     301 non-null    int64
#  4   bedCount     296 non-null    float64
#  5   instkind     300 non-null    object
#  6   revenue      293 non-null    float64
#  7   salary       293 non-null    float64
#  8   profit       293 non-null    float64
#  9   debt         293 non-null    float64
#  10  netAsset     293 non-null    float64
#  11  employee     291 non-null    float64
#  12  ownerChange  289 non-null    object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 30.7+ KB

# %%
#통계 정보
df.describe().drop('openDate',axis=1)
# Out:
#           inst_id    bedCount       revenue        salary        profit  \
# count  301.000000  296.000000  2.930000e+02  2.930000e+02  2.930000e+02
# mean   219.056478  145.709459  1.288175e+10  5.654115e+09  2.101700e+08
# std    121.234869  118.923890  2.043543e+10  8.083343e+09  1.134673e+09
# min      1.000000    0.000000  0.000000e+00  0.000000e+00 -4.696701e+09
# 25%    112.000000   52.750000  3.252112e+09  1.626053e+09 -2.168279e+06
# 50%    230.000000  136.500000  5.524218e+09  2.659892e+09  8.130751e+07
# 75%    321.000000  193.000000  1.274839e+10  6.363400e+09  2.930329e+08
# max    428.000000  656.000000  1.510000e+11  6.403559e+10  7.475427e+09
#
#                debt      netAsset     employee
# count  2.930000e+02  2.930000e+02   291.000000
# mean   8.765310e+09  5.938213e+09   142.546392
# std    1.286112e+10  1.266035e+10   160.191073
# min    0.000000e+00 -2.019624e+10     0.000000
# 25%    1.953077e+09  1.224795e+09    53.500000
# ...

# %% [markdown]
# ## 4. 수치형 변수 값에 결측치가 하나라도 존재하는 병원 데이터 전체를 삭제

# %%
df[['inst_id', 'bedCount', 'revenue','salary', 'profit', 'debt', 'netAsset', 'employee']].dropna(axis=0)
# Out:
#      inst_id  bedCount       revenue        salary        profit  \
# 0          1     175.0  4.217530e+09  2.033835e+09  2.251697e+08
# 2          4     468.0  1.004522e+09  2.964023e+08  4.186475e+07
# 3          7     353.0  7.250734e+10  3.178605e+10  9.028303e+08
# 4          9     196.0  4.904354e+10  2.446078e+10  8.074970e+07
# 5         11     243.0  3.358054e+10  1.665533e+10 -4.622738e+07
# ..       ...       ...           ...           ...           ...
# 293      418     109.0  4.303270e+09  2.228914e+09  3.409870e+08
# 294      419     367.0  1.207963e+10  5.691328e+09  4.788074e+08
# 295      420       0.0  5.500472e+09  2.653680e+09  2.456945e+08
# 296      422     214.0  7.614697e+09  3.467861e+09  5.943868e+08
# 299      427     180.0  2.116892e+09  2.231944e+09 -1.850554e+09
#
#              debt      netAsset  employee
# 0    6.828260e+08  2.844460e+09      62.0
# 2    9.241434e+07  3.005088e+08     234.0
# 3    4.236380e+10  1.385710e+10     663.0
# ...

# %% [markdown]
# ## 5. 당기순이익이 높은 상위 10개 병원의 병원 고유 번호, 영업/폐업 분류, 병원 설립일, 병원 종류 정보 출력

# %%
df.sort_values('profit',ascending=False)[['inst_id','OC','openDate','instkind']].head(10)
# Out:
#      inst_id    OC  openDate          instkind
# 292      417  open  20020401  general_hospital
# 276      390  open  20071031  nursing_hospital
# 272      383  open  20160826          hospital
# 273      384  open  20140804  general_hospital
# 221      317  open  20070104  general_hospital
# 267      375  open  19920801          hospital
# 245      350  open  19970728            clinic
# 75       112  open  20070807  nursing_hospital
# 41        65  open  20110512          hospital
# 243      347  open  19920930          hospital

# %% [markdown]
# ## 6. 병원 종류 별 총 직원 수의 평균값 출력

# %%
df[['instkind','employee']].groupby('instkind').mean()
# Out:
#                         employee
# instkind
# clinic                 84.764706
# dental_clinic         107.000000
# general_hospital      406.216216
# hospital              125.488095
# nursing_hospital       97.822695
# traditional_clinic     79.666667
# traditional_hospital   45.000000

# %% [markdown]
# ## 7. 대표자가 변동된 병원들의 병원 고유 번호, 영업 폐업 분류 출력

# %%
df[['inst_id','OC']][df['ownerChange']=='change']
# Out:
#      inst_id      OC
# 12        22    open
# 16        33    open
# 17        34    open
# 21        38    open
# 22        39    open
# 35        58   close
# 63        97    open
# 72       108    open
# 90       137    open
# 96       144    open
# 109      162    open
# 136      202    open
# 139      205    open
# 140      208    open
# 142      211    open
# 158      238   close
# 163      247    open
# 176      264    open
# 177      265   close
# 189      277    open
# 193      281   close
# 200      289    open
# 202      291    open
# 204      296    open
# 213      308    open
# 214      309   close
# 219      315    open
# 227      323    open
# 228      324    open
# 247      352    open
# 250      355    open
# 251      356    open
# 255      360    open
# 268      376    open
# 269      378    open
# 274      385    open
# 275      386    open
# 284      406    open
# 286      408    open
# 287      409    open
# 289      412    open
# 290      414   close

# %% [markdown]
# ## 8. 병원 종류 별 평균 급여를 boxplot 으로 출력

# %%
plt.boxplot(df[['instkind','salary']].groupby('instkind').mean())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18619dbd188>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18619df1a08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18619c92908>],
#  'medians': [<matplotlib.lines.Line2D at 0x18619df1e88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18619df1f48>],
#  'means': []}
